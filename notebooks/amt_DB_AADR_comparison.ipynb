# %%
# set dir to /home/dodo/projects/aDNA_Comparative_Analysis
import os
import pandas as pd
os.chdir('../../aDNA_Comparative_Analysis')
import re
from Bio import SeqIO

# %%
from src.data_loading import load_data, load_mt_dataset
from src.data_processing import DataProcessor
from src.parsing import match_reich_metadata

# %%
# metadata_file -> AmtDB csv metadata file
# fasta_amtdb -> AmtDB fasta file
# anno_file -> Reich annotation file = metadata file
# fasta_reich -> Reich fasta file

metadata_file = 'data/amtDB/amtdb_metadata.csv'
fasta_amtdb = 'data/amtDB/amtdb_1621-samples_7f_a0pkh.fasta'
anno_file = 'data/mitogenomes_reich/v54.1.p1_1240K_public/v54.1.p1_1240K_public.anno'
fasta_reich = 'data/mitogenomes_reich/mtdna_reich.fasta'

# %%
meta_amtDB, ids_seq_fasta = load_data(metadata_file, fasta_amtdb)
ids_mt_dataset, meta_mt_dataset = load_mt_dataset(fasta_reich, anno_file)
# Out:
# Loading AmtDB metadata from 'data/amtDB/amtdb_metadata.csv' and sequence IDs from 'data/amtDB/amtdb_1621-samples_7f_a0pkh.fasta'...
# Loaded AmtDB metadata with 2541 records and 1621 sequences.
#
# Loading 'Reich mt dataset' from 'data/mitogenomes_reich/mtdna_reich.fasta' and metadata from 'data/mitogenomes_reich/v54.1.p1_1240K_public/v54.1.p1_1240K_public.anno'...
# Loaded 'Reich mt dataset' with 4122 sequences and metadata with 16388 records.

# %%
# Process AmtDB data to find missing sequences
processor_amtDB = DataProcessor(meta_amtDB, fasta_amtdb)
missing_ids_amtDB = processor_amtDB.find_missing_sequences()
# Out:
# Found 920 missing sequences.

# %%
# intersection of missing sequences in AmtDB and Master ID from meta_mt_dataset
missing_ids_amtDB_reich = list(set(missing_ids_amtDB) & set(meta_mt_dataset['Master ID']) )
len(missing_ids_amtDB_reich)
# Out:
# 529

# %%
# Extract missing sequences from the Reich dataset (fasta_reich) and save them
output_fasta = "output/missing_sequences_AmtDB.fasta"
processor_amtDB.extract_and_save_sequences(fasta_reich, missing_ids_amtDB, output_fasta)
# Out:
# Extracting sequences matching the specified IDs from 'data/mitogenomes_reich/mtdna_reich.fasta'...
# Saved 404 sequences to 'output/missing_sequences_AmtDB.fasta'.

# %% [markdown]
# ## using mithopathotool for haplogroups extraction

# %%
# !haplogrep3 classify --tree phylotree-rcrs@17.0 --in output/missing_sequences_AmtDB.fasta --out output/analysis_result.hsd --extend-report
# Out:
# Haplogrep 3 3.2.1
# (c) 2022-2023 Sebastian Schönherr, Hansi Weissensteiner, Lukas Forer
# [M::bwa_idx_load_from_disk] read 0 ALT contigs
# Written haplogroups to file output/analysis_result.hsd

# %%
# load analysis_result.hsd
analysis_result = pd.read_csv('output/analysis_result.hsd', sep='\t')
analysis_result.head(10)
# Out:
#   SampleID Haplogroup  Rank  Quality  \
# 0    I0070     H13a1a     1   0.9691
# 1    I0071       U5a1     1   0.9644
# 2    I0073          H     1   0.7942
# 3    I0074         H5     1   0.9043
# 4    I0108       H5a3     1   0.9663
# 5    I0111       H3ao     1   0.8935
# 6    I0112    H13a1a2     1   0.9605
# 7    I0113       J1c5     1   0.9271
# 8    I0118   HV+16311     1   0.8815
# 9    I0171    U5a1a2a     1   0.9762
#
#                                                Range Not_Found_Polys  \
# 0                                            1-16569             NaN
# 1                                            1-16569             NaN
# 2                                            1-16569             NaN
# 3                                            1-16569             NaN
# 4                        3-16568 16570-16569 1-16569             NaN
# 5                        3-16568 16570-16569 1-16569             NaN
# 6                        3-16568 16570-16569 1-16569             NaN
# 7  27-253 266-297 317-609 645-943 958-1391 1399-1...             NaN
# 8                        3-16568 16570-16569 1-16569             NaN
# 9                        3-16568 16570-16569 1-16569          573.XC
#
#                                          Found_Polys  \
# 0  263G 750G 1438G 2259T 4745G 4769G 8860G 13680T...
# 1  73G 263G 750G 1438G 2706G 3197C 4769G 7028T 88...
# 2                 263G 750G 1438G 4769G 8860G 15326G
# 3     263G 456T 750G 1438G 4769G 8860G 15326G 16304C
# 4  263G 456T 513A 750G 1438G 4336C 4769G 8860G 15...
# 5    263G 750G 1438G 4769G 6776C 8860G 15326G 16256T
# 6  263G 750G 1438G 2259T 4745G 4769G 8860G 13542G...
# 7  73G 185A 228A 295T 462T 489C 750G 1438G 2706G ...
# 8  263G 750G 1438G 2706G 4769G 7028T 8860G 15326G...
# 9  73G 263G 750G 1438G 1700C 2706G 3197C 4769G 53...
#
#                                      Remaining_Polys  \
# 0  310C (localPrivateMutation) 3107T (globalPriva...
# 1  310C (localPrivateMutation) 3107T (globalPriva...
# 2  3107T (globalPrivateMutation) 4216C (localPriv...
# 3  310C (localPrivateMutation) 3107T (globalPriva...
# 4  1N (globalPrivateMutation) 2N (globalPrivateMu...
# 5  1N (globalPrivateMutation) 2N (globalPrivateMu...
# 6  1N (globalPrivateMutation) 2N (globalPrivateMu...
# 7  195C (localPrivateMutation) 254N (globalPrivat...
# 8  1N (globalPrivateMutation) 2N (globalPrivateMu...
# 9  1N (globalPrivateMutation) 2N (globalPrivateMu...
#
#                                    AAC_In_Remainings  \
# 0                                                NaN
# 1                      8705C [M60T| Codon 2 | ATP6 ]
# 2  4216C [Y304H| Codon 1 | ND1 ] 14249A [A142V| C...
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                     9025A [G167S| Codon 1 | ATP6 ]
# 7  6994G [D364G| Codon 2 | COX1 ] 8929C [T135P| C...
# 8                                                NaN
# 9                                                NaN
#
#                                         Input_Sample
# 0  263G 310C 750G 1438G 2259T 3107T 4745G 4769G 8...
# 1  73G 263G 310C 750G 1438G 2706G 3107T 3197C 476...
# 2  263G 750G 1438G 3107T 4216C 4769G 8860G 9078C ...
# 3  263G 310C 456T 750G 1438G 3107T 4769G 5955T 88...
# 4  1N 2N 263G 310C 456T 513A 750G 1438G 3107T 433...
# 5  1N 2N 263G 309d 750G 1438G 3107C 4577T 4769G 6...
# 6  1N 2N 263G 309d 750G 1438G 2259T 3107T 4745G 4...
# 7  73G 185A 195C 228A 254N 255N 256N 257N 258N 25...
# 8  1N 2N 263G 296T 309d 750G 1438G 2706G 3107C 47...
# 9  1N 2N 73G 263G 310C 750G 1438G 1700C 2706G 310...

# %%
# columns
analysis_result.columns
# Out:
# Index(['SampleID', 'Haplogroup', 'Rank', 'Quality', 'Range', 'Not_Found_Polys',
#        'Found_Polys', 'Remaining_Polys', 'AAC_In_Remainings', 'Input_Sample'],
#       dtype='object')

# %%
# Rename 'SampleID' column to 'ID'
analysis_result.rename(columns={'SampleID': 'ID'}, inplace=True)

# %%
# Use 'Found_Polys' as the 'Polymorphisms' column directly
# Assuming 'Found_Polys' accurately represents the polymorphisms we want to include
# If a combination of columns is needed, you may need to concatenate them appropriately here
analysis_result['Polymorphisms'] = analysis_result['Found_Polys']

# %%
# !python3 mitopatho/mitopatho.py -i output/processed_haplogroups.hsd -o output/mitopatho_output.csv
# Out:
# ###########################################################################
# # MitoPathoPy - Tool for annotating pathological mutations in human mtDNA #
# ###########################################################################
# Author: Edvard Ehler, PhD (edvard.ehler@img.cas.cz)
# Year: 2020
# Source: https://github.com/EdaEhler/MitoPathoPy
#
# This tool will search for the (potential) pathological mutations in you mtDNA samples. To get the right input format, please, use the Haplogrep 2 (https://haplogrep.i-med.ac.at/app/index.html) tool to turn your sequences (fastas) into HSD format file. Haplogrep can be also downloaded and run localy (https://github.com/seppinho/haplogrep-cmd). Pathological mtDNA mutations are taken from data published at https://www.mitomap.org/MITOMAP.
#
# We invite you to check our ancient mtDNA database at: https://amtdb.org/
#
# If you use this tool in you research, please, consider citing our article:
# Ehler E, Novotný J, Juras A, Chyleński M, Moravčík O, Pačes J. AmtDB: a database of ancient human mitochondrial genomes. Nucleic acids research. 2019 Jan 8;47(D1):D29-32.
#
# ###########################################################################

# %%
# load mitopatho_output.txt
mitopatho_output = pd.read_csv('output/mitopatho_output.csv', sep='\,')

# %%
mitopatho_output
# Out:
#         ID                                         Unnamed: 1
# 0    I0070                                                NaN
# 1    I0071  11467G,Altered brain pH / sCJD patients,Report...
# 2    I0073                                                NaN
# 3    I0074                                                NaN
# 4    I0108  4336C,ADPD / Hearing Loss & Migraine / autism ...
# ..     ...                                                ...
# 399  I9127  150T,Longevity / Cervical Carcinoma / HPV infe...
# 400  I9128  10398G,PD protective factor / longevity / alte...
# 401  I9129                                                NaN
# 402  I9130  150T,Longevity / Cervical Carcinoma / HPV infe...
# 403  I9131  9055A,PD protective factor,Reported;10398G,PD ...
#
# [404 rows x 2 columns]

# %%
# pprint first two rows of the DataFrame but full data 
id_1 = mitopatho_output[mitopatho_output['ID'] == 'I0071']
# print second column of the first row
id_1.iloc[0, 1]
# Out:
# '11467G,Altered brain pH / sCJD patients,Reported;12308G,CPEO / Stroke / CM / Breast & Renal & Prostate Cancer Risk / Altered brain pH /sCJD,Reported;12372A,Altered brain pH / sCJD patients,Reported;16192T,Melanoma patients,Reported;16270T,Melanoma patients,Reported'

# %%
missing_ids_amtDB = processor_amtDB.find_missing_sequences()
ids_mt_dataset, meta_mt_dataset = load_mt_dataset(fasta_reich, anno_file)
# Out:
# Found 920 missing sequences.
#
# Loading 'Reich mt dataset' from 'data/mitogenomes_reich/mtdna_reich.fasta' and metadata from 'data/mitogenomes_reich/v54.1.p1_1240K_public/v54.1.p1_1240K_public.anno'...
# Loaded 'Reich mt dataset' with 4122 sequences and metadata with 16388 records.

# %%
# how many missing_ids_amtDB in the reich dataset
missing_ids_amtDB_in_reich = [id for id in missing_ids_amtDB if id in meta_mt_dataset['Master ID'].values]
print(f"Number of missing sequences in AmtDB that are in the Reich dataset: {len(missing_ids_amtDB_in_reich)}")
# Out:
# Number of missing sequences in AmtDB that are in the Reich dataset: 529

# %%
mitopatho_csv_path = 'output/AmtDB MitoPathoTool.csv'
mitop_data = pd.read_csv(mitopatho_csv_path)
mitop_data
# Out:
#          ID Polymorphism  Position  \
# 0     I0071       11467G     11467
# 1     I0071       12308G     12308
# 2     I0071       12372A     12372
# 3     I0071       16192T     16192
# 4     I0071       16270T     16270
# ...     ...          ...       ...
# 1704  I9131       10398G     10398
# 1705  I9131       11467G     11467
# 1706  I9131       12308G     12308
# 1707  I9131       12372A     12372
# 1708  I9131        9055A      9055
#
#                                              Status    Locus  \
# 0                                          Reported   MT-ND4
# 1                                          Reported   MT-TL2
# 2                                          Reported   MT-ND5
# 3                                          Reported    MT-CR
# 4                                          Reported    MT-CR
# ...                                             ...      ...
# 1704  Reported / lineage L & M marker / also hg IJK   MT-ND3
# 1705                                       Reported   MT-ND4
# 1706                                       Reported   MT-TL2
# 1707                                       Reported   MT-ND5
# 1708                                       Reported  MT-ATP6
#
#                                                Diseases Homoplasmy  \
# 0                      Altered brain pH / sCJD patients          +
# 1     CPEO / Stroke / CM / Breast & Renal & Prostate...          +
# 2                      Altered brain pH / sCJD patients          +
# 3                                     Melanoma patients         nr
# 4                                     Melanoma patients         nr
# ...                                                 ...        ...
# 1704  PD protective factor / longevity / altered cel...          +
# 1705                   Altered brain pH / sCJD patients          +
# 1706  CPEO / Stroke / CM / Breast & Renal & Prostate...          +
# 1707                   Altered brain pH / sCJD patients          +
# 1708                               PD protective factor          +
#
#      Heteroplasmy
# 0               -
# 1               +
# 2               -
# 3              nr
# 4              nr
# ...           ...
# 1704            -
# 1705            -
# 1706            +
# 1707            -
# 1708            -
#
# [1709 rows x 8 columns]

# %%
# number of sequence IDs matched from mitop_data and missing_ids_amtDB_in_reich
matched_ids = [id for id in missing_ids_amtDB_in_reich if id in mitop_data['ID'].values]
print(f"Number of sequence IDs matched from mitop_data and missing_ids_amtDB_in_reich: {len(matched_ids)}")
# Out:
# Number of sequence IDs matched from mitop_data and missing_ids_amtDB_in_reich: 325

# %%
# Example of how to call the function with paths to your CSV files
reich_meta_file_path = 'data/mitogenomes_reich/v54.1.p1_1240K_public/v54.1.p1_1240K_public.anno'
mitopatho_csv_path = 'output/AmtDB MitoPathoTool.csv'
missing_ids = missing_ids_amtDB

# Now, match metadata with the updated function that includes MitoPatho data
matched_metadata_df = match_reich_metadata(reich_meta_file_path, missing_ids, mitopatho_csv_path)
print(f"Total matched rows: {len(matched_metadata_df)}")
# Out:
# Reading Reich metadata...
# Reich metadata has 16388 rows.
# MitoPatho data has 1709 rows.
# Processed 561 out of 920 missing IDs.
# Total matched rows: 561

# %%
#  save the matched metadata to a file
matched_metadata_df.to_csv('output/matched_metadata.csv', index=False)
matched_metadata_df
# Out:
#     identifier    alternative_identifiers  country continent region  \
# 0        I1072           I1072_enhanced_d   Israel
# 1        I1072                    I1072_d   Israel
# 2        I1072                      I1072   Israel
# 3        I1415             I1415_enhanced   Jordan
# 4        I1701             I1701_enhanced   Jordan
# ..         ...                        ...      ...       ...    ...
# 556     ILK002                     ILK002  Ukraine
# 557     ILK001                     ILK001  Ukraine
# 558     ILK003                     ILK003  Ukraine
# 559      I1944  S1944.E1.L3_v54.1_addback     Iran
# 560      I1951  S1951.E1.L3_v54.1_addback     Iran
#
#                          culture epoch                        group comment  \
# 0              Israel_Natufian_d                  Israel_Natufian_d
# 1                Israel_Natufian                    Israel_Natufian
# 2         Israel_Natufian_contam             Israel_Natufian_contam
# 3                    Jordan_PPNB                        Jordan_PPNB
# 4                    Jordan_PPNB                        Jordan_PPNB
# ..                           ...   ...                          ...     ...
# 556  Ukraine_EBA_GlobularAmphora        Ukraine_EBA_GlobularAmphora
# 557      Ukraine_GlobularAmphora            Ukraine_GlobularAmphora
# 558      Ukraine_GlobularAmphora            Ukraine_GlobularAmphora
# 559             Iran_GanjDareh_N                   Iran_GanjDareh_N
# 560             Iran_GanjDareh_N                   Iran_GanjDareh_N
#
#         latitude  ...     ychr_snps avg_coverage sequence_source  \
# 0          32.65  ...            ..     8.193132           fasta
# 1          32.65  ...            ..     1.897519           fasta
# 2          32.65  ...            ..    12.656105           fasta
# 3         31.988  ...            ..    23.444746           fasta
# 4         31.988  ...  n/a (female)    14.818215           fasta
# ..           ...  ...           ...          ...             ...
# 556  49.55777778  ...            ..           ..           fasta
# 557  49.55777778  ...            ..           ..           fasta
# 558  49.55777778  ...  n/a (female)           ..           fasta
# 559        34.45  ...            ..     4.453256           fasta
# 560        34.45  ...            ..    13.102963           fasta
#
#                             mitopatho_alleles  \
# 0                         12705T;16390A;8836G
# 1                         12705T;16390A;8836G
# 2                         12705T;16390A;8836G
# 3            11251G;15928A;16189C;4216C;4917G
# 4    10398G;11467G;12308G;12372A;16093C;9055A
# ..                                        ...
# 556
# 557
# 558
# 559                                     4216C
# 560
#
#                     mitopatho_positions  \
# 0                      12705;16390;8836
# 1                      12705;16390;8836
# 2                      12705;16390;8836
# 3           11251;15928;16189;4216;4917
# 4    10398;11467;12308;12372;16093;9055
# ..                                  ...
# 556
# 557
# 558
# 559                                4216
# 560
#
#                                mitopatho_locus  \
# 0                         MT-CO1;MT-CR;MT-ATP6
# 1                         MT-CO1;MT-CR;MT-ATP6
# 2                         MT-CO1;MT-CR;MT-ATP6
# 3             MT-ND4;MT-TT;MT-CR;MT-ND1;MT-ND2
# 4    MT-ND3;MT-ND4;MT-TL2;MT-ND5;MT-CR;MT-ATP6
# ..                                         ...
# 556
# 557
# 558
# 559                                     MT-ND1
# 560
#
#                                     mitopatho_diseases  \
# 0    Possible protective factor for normal tension ...
# 1    Possible protective factor for normal tension ...
# 2    Possible protective factor for normal tension ...
# 3    Reduced risk of PD;Multiple Sclerosis / idiopa...
# 4    PD protective factor / longevity / altered cel...
# ..                                                 ...
# 556
# 557
# 558
# 559  LHON / Insulin Resistance /possible adaptive h...
# 560
#
#                                     mitopatho_statuses mitopatho_homoplasms  \
# 0                                             Reported               <NA>;+
# 1                                             Reported               <NA>;+
# 2                                             Reported               <NA>;+
# 3                         Reported;Conflicting reports                 nr;+
# 4    Reported / lineage L & M marker / also hg IJK;...                  +;-
# ..                                                 ...                  ...
# 556
# 557
# 558
# 559                                Conflicting reports                    +
# 560
#
#     mitopatho_heteroplasms
# 0                   <NA>;-
# 1                   <NA>;-
# 2                   <NA>;-
# 3                     nr;-
# 4                      -;+
# ..                     ...
# 556
# 557
# 558
# 559                      -
# 560
#
# [561 rows x 33 columns]

# %% [markdown]
# ## Seq with same identificator found in missing fasta sequences
# - the difference is just between the sequence ending using NNNNNN or --------

# %%
# load fasta file missing_sequences_AmtDB.fasta
fasta_file = 'output/missing_sequences_AmtDB.fasta'
fasta_reich = 'data/mitogenomes_reich/mtdna_reich.fasta'
# load fasta file
sequences = list(SeqIO.parse(fasta_reich, 'fasta'))
id_sequences = {seq.id for seq in sequences}
# from id_sequences, find the ids that are duplicated
id_sequences = [seq.id for seq in sequences]
duplicated_ids = [id for id in id_sequences if id_sequences.count(id) > 1]
duplicated_ids
# Out:
# ['I4188_enhanced',
#  'I16170_enhanced',
#  'I16170',
#  'I15947',
#  'I7341',
#  'I3315_enhanced',
#  'I13983',
#  'I13983_enhanced_d',
#  'I13983',
#  'I13983_enhanced_d',
#  'I15947',
#  'I16170',
#  'I16170_enhanced',
#  'I3315_enhanced',
#  'I4188_enhanced',
#  'I7341']

# %%
# extract these sequences from the fasta file and store them in a new file duplicates.fasta
output_fasta = "output/duplicates.fasta"
processor_amtDB.extract_and_save_sequences(fasta_reich, duplicated_ids, output_fasta)
# Out:
# Extracting sequences matching the specified IDs from 'data/mitogenomes_reich/mtdna_reich.fasta'...
# Saved 16 sequences to 'output/duplicates.fasta'.

# %%
# open with this with pandas: /home/dodo/projects/aDNA_Comparative_Analysis/data/aadr/dataverse_files/aadr_v54.1.p1_HO_public.anno
# load the metadata file
import pandas as pd
metadata_file = '/home/dodo/projects/aDNA_Comparative_Analysis/data/aadr/dataverse_files/aadr_v54.1.p1_HO_public.anno'
metadata = pd.read_csv(metadata_file, sep='\t')
metadata
# Out:
# /tmp/ipykernel_115489/834087549.py:5: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   metadata = pd.read_csv(metadata_file, sep='\t')
#                       Genetic ID  Master ID  \
# 0                        I001.HO       I001
# 1                        I002.HO       I002
# 2                   IREJ-T006.HO  IREJ-T006
# 3                   IREJ-T009.HO  IREJ-T009
# 4                   IREJ-T022.HO  IREJ-T022
# ...                          ...        ...
# 20497       I19456_v54.1_addback     I19456
# 20498  S1944.E1.L3_v54.1_addback      I1944
# 20499  S1951.E1.L3_v54.1_addback      I1951
# 20500  S7241.E1.L1_v54.1_addback      I7241
# 20501        I1877_v54.1_addback      I1877
#
#                              Skeletal code  Skeletal element  \
# 0                                       ..                ..
# 1                                       ..                ..
# 2                                       ..                ..
# 3                                       ..                ..
# 4                                       ..                ..
# ...                                    ...               ...
# 20497  Tell Kran 9; 4th removal, sample 37  bone (long bone)
# 20498              GD14B (Ganj Dareh #14b)           petrous
# 20499                GD39 (Ganj Dareh #39)           petrous
# 20500                                 VN33           petrous
# 20501               BAM13b | LP14.9=BAM13b           petrous
#
#       Year data from this individual was first published [for a present-day individuals we give the data of the data reported here; missing GreenScience 2010 (Vi33.15, Vi33.26), Olalde2018 (I2657), RasmussenNature2010 (Australian)]  \
# 0                                                   2016
# 1                                                   2016
# 2                                                   2016
# 3                                                   2016
# 4                                                   2016
# ...                                                  ...
# 20497                                               2022
# 20498                                               2016
# 20499                                               2016
# 20500                                                 ..
# 20501                                               2017
#
#                                              Publication  \
# 0                                   BroushakiScience2016
# 1                                   BroushakiScience2016
# 2                                   BroushakiScience2016
# 3                                   BroushakiScience2016
# 4                                   BroushakiScience2016
# ...                                                  ...
# 20497             LazaridisAlpaslanRoodenbergScience2022
# 20498  NarasimhanPattersonScience2019 (supplement of ...
# 20499  NarasimhanPattersonScience2019 (supplement of ...
# 20500                                                 ..
# 20501                                   LipsonNature2017
#
#       Method for Determining Date; unless otherwise specified, calibrations use 95.4% intervals from OxCal v4.4.2 Bronk Ramsey (2009); r5; Atmospheric data from Reimer et al (2020)  \
# 0                                                 Modern
# 1                                                 Modern
# 2                                                 Modern
# 3                                                 Modern
# 4                                                 Modern
# ...                                                  ...
# 20497                   Context: Archaeological - Period
# 20498                   Context: Archaeological - Period
# 20499                                   Direct: IntCal20
# 20500  Context: Based on other direct dates for site ...
# 20501                                   Direct: IntCal20
#
#        Date mean in BP in years before 1950 CE [OxCal mu for a direct radiocarbon date, and average of range for a contextual date]  \
# 0                                                      0
# 1                                                      0
# 2                                                      0
# 3                                                      0
# 4                                                      0
# ...                                                  ...
# 20497                                               4450
# 20498                                               9800
# 20499                                               9848
# 20500                                               3850
# 20501                                               7567
#
#        Date standard deviation in BP [OxCal sigma for a direct radiocarbon date, and standard deviation of the uniform distribution between the two bounds for a contextual date]  \
# 0                                                      0
# 1                                                      0
# 2                                                      0
# 3                                                      0
# 4                                                      0
# ...                                                  ...
# 20497                                                289
# 20498                                                 87
# 20499                                                135
# 20500                                                173
# 20501                                                 39
#
#       Full Date One of two formats. (Format 1) 95.4% CI calibrated radiocarbon age (Conventional Radiocarbon Age BP, Lab number) e.g. 2624-2350 calBCE (3990±40 BP, Ua-35016). (Format 2) Archaeological context range, e.g. 2500-1700 BCE  \
# 0                                                present
# 1                                                present
# 2                                                present
# 3                                                present
# 4                                                present
# ...                                                  ...
# 20497                                      3000-2000 BCE
# 20498                                      8000-7700 BCE
# 20499           8198-7613 calBCE (8800±50 BP, Poz-81109)
# 20500                                      2200-1600 BCE
# 20501          5713-5556 calBCE (6704±34 BP, MAMS-11933)
#
#        ... Y haplogroup (manual curation in ISOGG format)  \
# 0      ...                                             ..
# 1      ...                                             ..
# 2      ...                                             ..
# 3      ...                                             ..
# 4      ...                                             ..
# ...    ...                                            ...
# 20497  ...                                             ..
# 20498  ...                                             ..
# 20499  ...                                             ..
# 20500  ...                                             ..
# 20501  ...                                             ..
#
#       mtDNA coverage (merged data) mtDNA haplogroup if >2x or published  \
# 0                               ..                                   ..
# 1                               ..                                   ..
# 2                               ..                                   ..
# 3                               ..                                   ..
# 4                               ..                                   ..
# ...                            ...                                  ...
# 20497                   275.284628                               U2e1a1
# 20498                     4.453256                             R2+13500
# 20499                    13.102963                                   HV
# 20500                     4.831855                                    R
# 20501                    41.621824                                  X2d
#
#       mtDNA match to consensus if >2x (merged data)  \
# 0                                                ..
# 1                                                ..
# 2                                                ..
# 3                                                ..
# 4                                                ..
# ...                                             ...
# 20497                                  [0.99,0.998]
# 20498                                 [0.861,0.975]
# 20499                                     [0.983,1]
# 20500                                 [0.859,0.973]
# 20501                                 [0.976,0.994]
#
#       Damage rate in first nucleotide on sequences overlapping 1240k targets (merged data)  \
# 0                                                     ..
# 1                                                     ..
# 2                                                     ..
# 3                                                     ..
# 4                                                     ..
# ...                                                  ...
# 20497                                              0.249
# 20498                                              0.109
# 20499                                              0.332
# 20500                                              0.262
# 20501                                              0.114
#
#       Sex ratio [Y/(Y+X) counts] (merged data)  \
# 0                                           ..
# 1                                           ..
# 2                                           ..
# 3                                           ..
# 4                                           ..
# ...                                        ...
# 20497                                    0.413
# 20498                                    0.017
# 20499                                    0.016
# 20500                                    0.392
# 20501                                    0.389
#
#       Library type (minus=no.damage.correction, half=damage.retained.at.last.position, plus=damage.fully.corrected, ds=double.stranded.library.preparation, ss=single.stranded.library.preparation)  \
# 0                                                     ..
# 1                                                     ..
# 2                                                     ..
# 3                                                     ..
# 4                                                     ..
# ...                                                  ...
# 20497                                            ss.half
# 20498                                            ds.half
# 20499                                            ds.half
# 20500                                            ds.half
# 20501                                            ds.half
#
#              Libraries                        ASSESSMENT  \
# 0                   ..                              PASS
# 1                   ..                              PASS
# 2                   ..                              PASS
# 3                   ..                              PASS
# 4                   ..                              PASS
# ...                ...                               ...
# 20497  S19456.Y1.E1.L1  PROVISIONAL_QUESTIONABLE_ADDBACK
# 20498      S1944.E1.L3          PROVISIONAL_PASS_ADDBACK
# 20499      S1951.E1.L3          PROVISIONAL_PASS_ADDBACK
# 20500      S7241.E1.L1          PROVISIONAL_PASS_ADDBACK
# 20501         S2341.L1          PROVISIONAL_PASS_ADDBACK
#
#       ASSESSMENT WARNINGS (Xcontam interval is listed if lower bound is >0.005, "QUESTIONABLE" if lower bound is 0.01-0.02, "QUESTIONABLE_CRITICAL" or "FAIL" if lower bound is >0.02) (mtcontam confidence interval is listed if coverage >2 and upper bound is <0.
# 0                                                     ..
# 1                                                     ..
# 2                                                     ..
# 3                                                     ..
# 4                                                     ..
# ...                                                  ...
# 20497                              xcontam=[0.013,0.036]
# 20498                                                 ..
# 20499                                                 ..
# 20500                                                 ..
# 20501                                                 ..
#
# [20502 rows x 35 columns]
